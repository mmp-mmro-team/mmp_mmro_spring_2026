# %% [markdown]
# # Машинное обучение, ВМК МГУ
#
# # Практическое задание 4. Optimal Control Reinforcement Learning
#
# ### Авторы: **Афанасьев Глеб, Брескану Никита**
#
# ## Общая информация
# Дата выдачи: 01.05.2026
#
# Мягкий дедлайн: 16.05.2026 5:00 MSK
#
# Жёсткий дедлайн: 23.05.2026 5:00 MSK
#
# ## Оценивание и штрафы
# Каждая из задач имеет определенную «стоимость» (указана в скобках около задачи). **Максимальная оценка за работу  — 10 баллов + 9 бонусов.**
#
# Сдавать задание после указанного жёсткого срока сдачи нельзя. При выставлении неполного балла за задание в связи с наличием ошибок на усмотрение проверяющего предусмотрена возможность исправить работу на указанных в ответном письме условиях.
#
# Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов (подробнее о плагиате см. на странице курса). Если вы нашли решение какого-то из заданий (или его часть) в открытом источнике, необходимо указать ссылку на этот источник в отдельном блоке в конце вашей работы (скорее всего вы будете не единственным, кто это нашел, поэтому чтобы исключить подозрение в плагиате, необходима ссылка на источник).
#
# Неэффективная реализация кода может негативно отразиться на оценке.
#
# ## Формат сдачи !!ВАЖНО!!!
# Задания сдаются через систему anytask. Посылка должна содержать:
# * Ноутбук homework-practice-04-ocrl-Username.ipynb
#
#
# Username — ваша фамилия и имя на латинице именно в таком порядке

# %% [markdown]
# <p style="color:#de3815;font-size:25px;">
# Напоминание об оформлении и выполнении ноутбука
# </p>

# %% [markdown]
# * Все строчки должны быть выполнены. Нужно, чтобы output команды можно было увидеть, не запуская ячейки (кроме редких случаев, когда необходимо намеренно скрыть ненужный output, про такие случаи желательно писать пояснения в тексте). **В противном случае -1 балл**
# * При оформлении ДЗ нужно пользоваться данным файлом в качестве шаблона. Не нужно удалять и видоизменять написанный код и текст, если явно не указана такая возможность. **В противном случае -1 балл**
# * В anytask обязательно нужно прикреплять отдельно файл с расширением ipynb (не в архиве, а именно отдельно). Если необходимо отправить еще какие-то файлы, то вынесите их в отдельный архив (если файлов много) и пришлите. **В противном случае -0.5 балла**
# ---
# * Пишите, пожалуйста, выводы и ответы на вопросы в текстовых ячейках/при помощи print в коде. При их отсутствии мы не можем понять, сделали ли вы задание и понимаете, что происходит, и **поэтому будем снижать баллы**
# * Если алгоритм не сказано реализовывать явно, его всегда можно импортировать из библиотеки.
# ---
# * Про графики. _Штрафы будут применяться к каждому результату команды отображения графика (plt.show() и др. аналогичные). Исключением являются графики, генерируемые функциями каких-либо сторонних библиотек, если их нельзя кастомизировать_
#
#     * должно быть название (plt.title) графика; **В противном случае &ndash; -0.05 балла**
#     * на графиках должны быть подписаны оси (plt.xlabel, plt.ylabel); **В противном случае &ndash; -0.025 балла за каждую ось**
#     * должны быть подписаны единицы измерения (если это возможно); **В противном случае &ndash; -0.025 балла за каждую ось**
#     * все названия должны быть понятны любому человеку, знакомому с терминологией, без заглядывания в код; **В противном случае &ndash; -0.05 балла**
#     * подписи тиков на осях не должны сливаться как на одной оси, так и между ними; **В противном случае &ndash; -0.025 балла за каждую ось**
#     * если изображено несколько сущностей на одном холсте (например несколько функций), то необходима поясняющая легенда (plt.legend); **В противном случае &ndash; -0.05 балла**
#     * все линии на графиках должны быть чётко видны (нет похожих цветов или цветов, сливающихся с фоном); **В противном случае &ndash; -0.05 балла**
#     * если отображена величина, имеющая очевидный диапазон значений (например, проценты могут быть от 0 до 100), то желательно масштабировать ось на весь диапазон значений (исключением является случай, когда вам необходимо показать малое отличие, которое незаметно в таких масштабах);
#     * графики должны быть не супер-микро и не супер-макро по размерам, так, чтобы можно было увидеть все, что нужно.
#     * при необходимости улучшения наглядности графиков, можно пользоваться логарифмической шкалой по осям x/y.
#
#
# ### А также..
#
# * Для удобства поиска вопросов, на которые от вас просят ответа, мы пометили их знаком **(?)**
# * Знак **(!)** означает, что выполнение замечания необходимо для **возможности получения полного балла**
# * Даем до +0.5 балла за выдающиеся успехи по субъективному мнению проверяющих. Этот **бонус** не апеллируется
# * **За отсутствие выводов (или скудные выводы в духе "я реализовал метод, он работает") там, где их просят, проверяющий имеет право вычесть до 2.5 баллов вне зависимости от максимального балла за задание**

# %% [markdown]
# ## Задание 1 (4 балла): Оптимальное Управление

# %% [markdown]
# Начнем с небольшой разминки: реализация классического алгоритма нахождения оптимального управления для двухмерного дрона. Его динамика уже реализована за вас в файле qudrotor.py. Кроме того, реализована также визуализация его управления.
#
# В качестве описания текущего состояния предлагается использовать вектор из 6-ти элементов [x, dx, y, dy, theta, dtheta]:
#
# *   x - координата центра дрона по x
# *   dx - скорость центра дрона по x
# *   y - координата центра дрона по y
# *   dy - скорость центра дрона по y
# *   theta - угол наклона относительно оси x
# *   dtheta - угловая скорость
#
# В качестве управления используем вектор из 2 элементов [u1, u2]:
#
# *   u1 - сила тяги левого винта
# *   u2 - сила тяги правого винта
#
# Сила измеряется в ньютонах, прикладывается перпендикулярно линии, проведенной между двумя винтами.
#
# Задача: реализовать управление, реализуя которое можно достичь точки $x^*$

# %%
import numpy as np
import matplotlib.pyplot as plt

import quadrotor
import math
import sympy

# %% [markdown]
# Зададим параметы для дальнейшей работы:

# %%
m = 0.6 #масса дрона
r = 0.4 #длина дрона от левого до правого винта
I = 0.15 #инерция
g = 9.81 #ускорение свободного падения
dt = 0.01 #временной шаг

# %% [markdown]
# **Задание 1 (0.2 балла):** для начала проверим что все хорошо работает нормально. Реализуйте две функции-контроллера и проверьте их работу. Функции должны принимать на вход текущее состояние и номер таймстепа. Выдавать функции должны управление.
#
# Первая функция должна давать команду ничего не делать (то есть всегда выдавать нулевое управление)
#
# Вторая должна заставлять дрон висеть в воздухе при условии что он появляется в правильном положении параллельно оси x.

# %%
def do_nothing_controller(state, i):
    u = #ваш код здесь
    return u

def stabilize_controller(state, i):
    u = #ваш код здесь
    return u

# %% [markdown]
# Проверим реализации. В первом случае дрон должен падать вниз, во втором - висеть в точке (0, 0).

# %%
N = 1000
x0 = np.zeros([quadrotor.NUMBER_STATES,])
t, x, u = quadrotor.simulate(x0, do_nothing_controller, N, disturbance = False)

quadrotor.animate_robot(x, u)

# %%
N = 1000
x0 = np.zeros([quadrotor.NUMBER_STATES,])
t, x, u = quadrotor.simulate(x0, stabilize_controller, N, disturbance = False)

quadrotor.animate_robot(x, u)

# %% [markdown]
# **Задание 2 (1.8 баллов):** Как вы помните, уравнения Рикатти имеют место для задачи типа LQR. Однако, она имеет 2 требования, которые не выполняются в нашей задаче.
#
# **Требование 1:** динамика должна выглядеть следующим образом:
# $x_{k+1} = Ax_k + Bu_k$.
#
# **Требование 2:** функция потерь должна выглядеть следующим образом:
# $cost(x,u) = \sum_{k=0}^{N}x_k^TQx_k + u_kRu_k + x_N^TQx_N$
#
# Также была выведена универсальная формула получения оптимального управления без обратного прогона. Сделано это было при предположении $N=∞$. Поэтому, для нашей задачи тоже будем предполагать горизонт управления бесконечным. Таким образом, требование 2 переформулируется:
#
# **Требование 2':** функция потерь должна выглядеть следующим образом:
# $cost(x,u) = \sum_{k=0}^{∞}[x_k^TQx_k + u_kRu_k]$
#
#
# Для нашей задачи выписать матрицы A, B, Q и R в общем случае невозможно. Очевидным решением будет попробовать нашу динамику аппроксимировать линейной.
# Однако, даже если мы найдем аппроксимацию этих матриц, требование 2 не будет выполняться, так как перед нами стоит задача приведения дрона в конкретную точку $x^*$ и его последующая фиксация в этой точке . То есть, хочется минимизировать такой лосс: $cost(x,u) = \sum_{k=0}^{∞}(x_k-x^*)^TQ(x_k-x^*) + (u_k-u^*)^TR(u_k-u^*)$, где $u*$ - управление, стабилизирующее дрон в текущей точке. Самый простой выход в нашем случае - решать задачу в терминах расстояний до цели. То есть, новый вектор наблюдений теперь $\overline{x} = (x-x^*)$, управление -  $\overline{u}=(u-u^*)$
#
# 1. Выпишите функцию $f(x, u)$ через производную и приращение по времени dt, где $x_{n+1} = f(x_n, u_n)$, а $dt$ - продолжительность временного шага в секундах. Выразите эту функцию через элементы вектора наблюдений и управления. Keywords: второй закон Ньютона, линейное и угловое ускорение стержня, здравый смысл
#
# 2. С помощью разложения в ряд Тейлора в окрестности $x^*, u^*$ выведите функцию $\overline{f}: \overline{x}_{n+1} = \overline{f}(\overline{x}_{n}, \overline{u}_{n}) = A\overline{x}_{n} + B\overline{u}_{n}$
#
# 3. Запрограммируйте подсчет  матриц $A$ и $B$.

# %% [markdown]
# ВАШ ВЫВОД ЗДЕСЬ

# %%
def get_linearization(x, u):
    m = 0.6 #масса
    r = 0.4 #длина
    I = 0.15 #инерция
    g = 9.81 #ускорение свободного падения
    dt = 0.01 #длина временного шага
    #ваш код здесь

# %% [markdown]
# Если вы все реализоваи верно, нижняя ячейка должна выполняться без ошибок

# %%
x_cur = np.array([2,0,2,0,0,0])
u = np.array([4,4])
x_star = np.array([3,0,3,0,0,0])
A, B = get_linearization(x_star, stabilize_controller(x_cur, 0))
assert (A.shape == (6,6)), "размер матрицы А должен быть 6 на 6"
assert ((B.shape == (2,6)) or (B.shape == (6,2))), "размер матрицы B должен быть 6 на 2 или 2 на 6"
if (B.shape == (2,6)):
  B = B.T
for i in range(10):
  assert np.all(np.isclose(A@(x_cur-x_star)[:, None] + B@(u-stabilize_controller(x_cur, 0))[:, None]+x_star[:, None], quadrotor.get_next_state(x_cur, u)[:, None])), "матрицы А и В неверно реализованы"
  x_cur = quadrotor.get_next_state(x_cur, u)

# %% [markdown]
# **Задание 2. (2 балла):** Теперь перейдем к реализации функции управления. Напомним схему уравнений Риккати:
#
#
#
# 1.   Получаем решение уравнения $P= Q + A^T(P^{-1} + B^TR^{-1}B)^{-1}A$
# 2.   Получаем матрицу $G= (R+B^TPB)^{-1}B^TPA$
# 3.   Получаем оптимальное решение $u_i = -Gx_i, \forall i\geq 0$
#
# Уравнение из пункта 1 предлагалось решать как уравнение, правая часть которого является сжимающим отображением левой части, последовательно применяя к $P$ оператор Риккати.

# %% [markdown]
# Реализуйте функцию, вычисляющую для соответствующих $A, B, Q  и R$ матрицу $P$. Условием останова считать изменение нового вычисленного $P$ по норме Фробениуса меньше чем на $ϵ$.

# %%
def solve_Ricatti_eq(A, B, Q, R, eps=0.1):
    # ваш код здесь

# %% [markdown]
# Теперь настало время вычислить оптимальное управление. Реализуйте функцию, получающую на вход начальное состояние, целевое состояние и класс с динамикой квадрокоптера и дающее на выходе оптимальную пару. Условием достижения целевого состояния является приближение к нему по евклидовой норме на расстояние $delta$ и ближе. Возвращение  оптимальной пары происходит при достижении целевого состояния. Помните что мы решаем задачу в терминах относительного состояния и аппроксимированных матриц A и B. Поэтому, к вычисленному по формулам с семинара управлению требуется прибавить стабилизатор.

# %%
def Riccati_controller(pos, goal, quadrotor, delta=0.01):
    Q = 2*np.identity(6)*10000
    R = 2*np.identity(2)*0.0001
    #ваш код здесь
    return traj_x, traj_u # должны иметь размер Nx6 и Nx2 соответственно.

# %% [markdown]
# Проверим управление. Если вы все реализовали верно, все 4 теста будут отрабатывать корректно и на видео дрон должен прилетать в заданное состояние

# %%
opt_traj = Riccati_controller(np.array([0,0,0,0,0,0]), np.array([3,0,3,0,0,0]), quadrotor)
quadrotor.animate_robot(opt_traj[0].T, opt_traj[1].T)

# %%
opt_traj = Riccati_controller(np.array([3,0,3,0,0,0]), np.array([-3,0,3,0,0,0]), quadrotor)
quadrotor.animate_robot(opt_traj[0].T, opt_traj[1].T)

# %%
opt_traj = Riccati_controller(np.array([-3,0,3,0,0,0]), np.array([3,0,-3,0,0,0]), quadrotor)
quadrotor.animate_robot(opt_traj[0].T, opt_traj[1].T)

# %%
opt_traj = Riccati_controller(np.array([0,0,0,0,0,0]), np.array([10,0,10,0,0,0]), quadrotor)
quadrotor.animate_robot(opt_traj[0].T, opt_traj[1].T, xlim = [-12, 12], ylim = [-12, 12])

# %% [markdown]
# (?) Исследуйте реализованный метод. Можно ли с помощью него достичь любого состояния  из любого состояния? А любой точки на плоскости из любой точки на плоскости (имеется ввиду что все элементы вектора состояния кроме координат равны 0 на старте и финише)? Почему? Если на второй вопрос ответ отрицательный, приведите пример и объясните, в какой момент и почему он ломается.

# %% [markdown]
# ### Бонус 1 (0.5 баллов)
#
# Возможно, кому-то из вас стало плохо от количества обращений матриц в функциях выше. Однако, если вы помните, уравнения Риккати существуют в нескольких вариантах (подробнее - см семинар или [статью](https://www.researchgate.net/publication/286129306_New_Forms_of_Riccati_Equations_and_the_Further_Results_of_the_Optimal_Control_for_Linear_Discrete-Time_Systems)). В некоторых из них матричных обращений меньше. Попробуйте реализовать уравнения Риккати в новой форме. (?) Получилось ли улучшение по времени/качеству решения? Почему?

# %% [markdown]
# ### Бонус 1 (до 3 баллов)
#
# Как вы могли сделать вывод выше, данный метод плохо себя чувствует в некоторых ситуациях. Попробуйте его как-то улучшить чтобы расширить его множество достижимости.
#
# Если ваш дрон сможет долететь из [0, 0] в [18, 18] - получите 1 балл
#
# Если ваш дрон сможет долететь из [0, 0] в [25, 25] - получите 2 балла
#
# Если ваш дрон сможет долететь из [0, 0] в [50, 50] - получите 3 балла

# %% [markdown]
# ## Задание 2 (6 баллов): RL

# %% [markdown]
# Теперь рассмотрим один из изученных на семинарах методов обучения с подкреплением: A2C. Для реализиции будем использовать фреймворк vizdoom, создающий окружение и предоставляющий интерфейс для управления агентом в одноименной игре.

# %%
# !pip install vizdoom
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.1/28.1 MB 27.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# Сделаем пару импортов

# %%
import vizdoom
import time
import torch
from collections import deque
from torchvision import transforms
from copy import deepcopy
from torch.distributions import Categorical

# %% [markdown]
# Воспользуемся вспомогательной функцией-оберткой над фреймворком, предоставляющей интерфейс для удобного взаимодействия.

# %%
from vizdoom_wrapper import init_game, create_and_show_gif

# %% [markdown]
# Функция init_game создает виртуальную среду, в которой вам предстоит обучать агента. Изучим интерфейс взаимодействия с ней на примере работы (ВНИМАНИЕ: если вы запускаете код в колабе, далее все должно работать нормально, но если вы выполняете задание у себя локально, вам потребуется скачать из директории с дз на гитхабе файлы health_gathering.cfg и health_gathering.wad, поместить их рядом и далее во все вызовы init_game() подавать аргумент config_path='путь до health_gathering.cfg')

# %%
doom = init_game()

# %% [markdown]
# Для начала работы с симуляцией требуется ее перезапустить с помощью метода reset(). Он инициализирует управляемого агента в начальном состоянии и возвращает это самое состояние и метаинформацию, которая в рамках данного задания не важна.

# %%
state, _ = doom.reset()

# %% [markdown]
# В нашем случае, состояние - это изображение, которое должно показываться на экране игроку. Посмотрим на него.

# %%
print(type(state), state.shape)
# Out:
# <class 'torch.Tensor'> torch.Size([1, 3, 240, 320])

# %%
plt.imshow(state.squeeze(0).permute(1, 2, 0).cpu().numpy())
plt.axis('off')
plt.show()

# %% [markdown]
# Как мы видим, из метода состояние возвращается уже в пригодном для нейросетей виде

# %% [markdown]
# Еще один метод, который нам понадобится - метод step(). Он принимает на вход действие, которое агенту необходимо совершить в среде и выполняет его. В нашем случае, агент может совершить 3 действия: шагнуть вперед, повернуть направо и повернуть налево. Возвращает он 5 переменных. Нам потребуются первые 3 из них: состояние, полученное после выполнения действия, награда за выполнение действия и флаг того, завершена ли симуляция (например, по причине смерти агента или истечении времени симуляции).

# %%
next_state, reward, done, _, _ = doom.step(1)
plt.imshow(next_state.squeeze(0).permute(1, 2, 0).cpu().numpy())
plt.axis('off')
plt.show()

# %% [markdown]
# В конце работы с симуляцией ее нужно завершить следующим методом

# %%
doom.close()

# %% [markdown]
# Теперь сформулируем задачу, которую вам необходидимо решить:
#
# Агент спавнится в комнате с кислотой и рааз в какое-то время теряет здоровье. По комнате разбросаны аптечки. Подбирая их, агент восстанавливает здоровье. За каждый временной шаг когда агент жив, он получает награду +1. За смерть он получает штраф -100. Через 2100 временных шагов симуляция завершается. Ваша задача: обучить нейросеть, под руководством которой агент проживет от начала симуляции до конца.
#
# Если интересно, подробнее про окружения vizdoom можете почитать [тут](https://vizdoom.farama.org/environments/default/)

# %% [markdown]
# Напомним суть метода A2C:
#
# Есть 2 нейронный сети: Actor и Critic.
#
# Critic - по-сути функция, оценивающая ожидаемую награду, которую обучают под дискретное уравнение Беллмана.
#
# Actor - политика, которую мы обучаем максимизировать ожидаемую награду.

# %% [markdown]
# В классическом A2C лоссы для них выглядят следующим образом:
#
# $L_{actor} = -\frac{1}{MN} \sum_{m=0}^M \sum_{t=0}^N log(π(a_t^m|s_t^m))A(a_t^m, s_t^m)$
#
# $L_{critic} = \frac{1}{MN} \sum_{m=0}^M \sum_{t=0}^N (V(s_t^m) - y(s_t^m, a_t^m))$
#
# $y(s_t^m, a_t^m) = \sum_{t'=t}^{t''} γ^{t'-t} r(s_{t'}, a_{t'}) + γ^{t''-t+1} V(s_{t''})$, где $t\leq t''<N-1$

# %% [markdown]
# **Задание 1 (0.2 балла)**Перед созданием нейросетей, еще раз посмотрим на переменную, описывающую состояние объекта. Как упоминалось выше, это по-сути изобрашение с монитора игрока. Изображение цветное. Цвет не несет большой смысловой нагрузки, картинку можно обесцветить и понизить разрешение (например, до 84х84), тем самым уменьшив размерность признакового пространства. Функция init_game может принимать на вход переменную типа torchvision.transforms.transforms.Compose, содержащий в себе трансформации, которые будут применяться к изображению перед его выдачей. Создайте  переменную, выполняющую все преобразования выше, пересоздайте игру и отобразите состояние

# %%
transforms = #ваш код здесь
#ваш код здесь

# %% [markdown]
# **Задание 2 (0.5 баллов)**Заметим что сама по себе картинка не несет никакой информации о динамике окружающей среды, в которой динамические элементы присутствуют (например, падающие с неба аптечки). Одним из способов дать сети информации о динамике - подавать в нее не один кадр, а историю из нескольких кадров. Для этого реализуйте вспомогательную функцию, принимающую на вход текущее состояние, имеющуюся на данный момент историю и размер истории (stack_size), с  которым мы работаем. Результатом работы данной функции должен стать тензор, полученный конкатенацией по глубине последних stack_size состояний. Если номер временного шага меньше чем stack_size, можно заполнить ее дубликатами самого старого состояния.

# %%
def stack_frames(stacked_frames, state, is_new_episode, stack_size, device):
    #ваш код здесь

# %% [markdown]
# Таким образом, теперь состоянием объекта мы считаем его реальное текущее состояние и историю из stack_size-1 последних предшествующих состояний.

# %% [markdown]
# **Задание 3 (5.3 балла)**Теперь создайте 2 вышеупомянутые нейросети. Так как пространство действий дискретно, вам  надо будет пробросить градиент через семплирование с вероятностями. В этом вам поможет torch.distributions.Categorical как возвращаемое значение Actor.
#
# В качестве архитектуры рекомендуется взять какую-либо сверточную архитектуру для работы с изображениями с линейным слоем на конце. Однако стоит отметить что в случае с RL нам важна вся осмысленная информания, которую мы можем вытянуть из изображения, в то время как maxpool или ReLU может ее просто занулить. В силу чего не рекомендуется использовать в архитектуре функции, отбрасывающие информацию или забивающие ее константой (уменьшение размера изображения в начале - исключение, так как там мы убедились что ничего важного оно не стирает). Используйте другие слои и другие функции активации.

# %%
class Actor(nn.Module):
    def __init__(self, state_size, action_size):
        super(Actor, self).__init__()

        #ваш код здесь

    def forward(self, state):
        #ваш код здесь

    def _reset_weights(self):
        for layer in self.layers:
            if isinstance(layer, torch.nn.Linear):
                torch.nn.init.kaiming_normal_(layer.weight)

class Critic(nn.Module):
    def __init__(self, state_size, action_size):
        super(Critic, self).__init__()

        #ваш код здесь

    def forward(self, state):
        #ваш код здесь

    def _reset_weights(self):
        for layer in self.layers:
            if isinstance(layer, torch.nn.Linear):
                torch.nn.init.kaiming_normal_(layer.weight)

# %% [markdown]
# Теперь для удобства реализуем функцию compute_returns, вычисляющую значения Q - функции. На вход она получает список rewards наград, получаемых на каждом шаге куска траектории, next_state - выход критика в последнем состоянии таектории. При обучении мы будем последовательно генерировать кусок траектории фиксированной длины (из соображений удобства). На выходе вы должны получить оценку Q-функции по формулам с семинара

# %%
def compute_Q(next_value, rewards, dones, vals, gamma=0.99):
    #ваш код здесь

# %% [markdown]
# И теперь, наконец, реализуйте алгоритм обучения A2C.
#
# Подсказка 1: Actor и Critic - разные сущености и не всегда их имеет смысл обновлять с одинаковой частотой.
#
# Подсказка 2: во избежание переобучения, рекомендуем  с небольшим коэффициентом прибавлять (до умножения на -1) к лоссу actor-а энтропию предсказаний этой сети. Это позволит ему лучше исследовать окружающую среду.

# %%
def train_a2c(n_epochs: int = 100, episode_length: int = 300):
    device = torch.device('cuda')
    lr=0.001
    stack_size = 4

    #создайте нейросети и оптимизаторы

    #создайте переменную - симулятор

    for iter in range(n_epochs):
        #обнулите окружение и получите первое состояние, создайте историю состояний



        for i in range(episode_length):
            #получите действие и значение V - функции в текущем состоянии state
            #ваш код здесь

            #шаг симулятора
            next_state, reward, done, _, _ = #ваш код здесь

            #накапливаем логарифмы вероятностей, значения v-функции, действия, награды, индикаторы завершения эпизода
            #ваш код здесь

 #получите значение V - функции в последнем состоянии (параметр next_state)
        #ваш код здесь

        #вычислите Q-функции
        #ваш код здесь

        #вычислите advantage
        advantage = #ваш код здесь

        #вычислите actor_loss
        actor_loss = #ваш код здесь

        #вычислите critic_loss
        critic_loss = #ваш код здесь

        #сделайте шаг оптимизации critic_loss
        #ваш код здесь

    torch.save(actor, 'actor.pkl')
    torch.save(critic, 'critic.pkl')
    doom.close()

    return actor, critic, actor_losses, critic_losses, rewards

actor, critic, a_losses, c_losses, reward_losses = train_a2c(n_epochs=3000, episode_length=2000)

# %% [markdown]
# Проверьте обученную сеть. Прикрепите ее веса вместе с ноутбуком. Для получения полного балла хотя бы в 5 из 10 запусков подряд агент должен жить более 1200 шагов симуляции (слово "подряд относится только к 10 тестовым запускам, 5 успешных внутри этих 10 подряд идти не обязаны)

# %%
doom = init_game(window_visible=False)
device = torch.device('cuda')
actor =
critic =

stack_size = 4
state, _ = doom.reset()

for i in range(2100):
    #реализуйте цикл игры под управлением вашей нейросети


doom.close()
# Out:
# Iteration: <built-in function iter>, Score: 5542

# %% [markdown]
# Отобразите запись игры в виде гифки

# %%
create_and_show_gif(doom.images)

# %% [markdown]
# (?) Сделайте выводы о работе медода, его сходимости, характерных особенностях его обучения.

# %% [markdown]
# ### Бонус (до 2 баллов)
#
# Улучшите как-нибудь (по скорости обучения, стабильности и т.д.) реализованный метод. Для получения полного балла нужно чтобы агент не более чем за 1500 итераций стабильно жил до конца симуляции 9 из 10 запусков подряд. Приложите веса сети к ноутбуку

# %% [markdown]
# ### Бонус (до 3 баллов)
# Решите еще какую-нибудь задачу из vizdoom с помощью А2С и его модификаций. За каждую задачу будет ставиться до 1 балла в зависимости от качества решения.

# %% [markdown]
# ### Бонус (0.5 баллов)
# Приложите какой-нибудь мем про оптимальное управление, или РЛ. Можно просто картинку, или текст, описывающий опыт выполнения данного дз. Или просто историю с майских расскажите какую-нибудь, ато скучно домашки проверять.
